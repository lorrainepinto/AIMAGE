# %% [markdown]
# This code is to apply the feather-like filter Prashanth specified.
# Not completely implemented to needed specification.

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
from PIL import Image,ImageFilter

# %%
img = cv2.imread('test2.png')
rgb  = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
blur = cv2.blur(rgb,(5,5))
plt.imshow(blur)

# %%
new_image = Image.fromarray(bl)
new_image.save("bl19.png")

# %%
gb = cv2.GaussianBlur(rgb,(5,5),0)
plt.imshow(gb)

# %%
median = cv2.medianBlur(rgb,9)
plt.imshow(median)

# %%
bl = cv2.bilateralFilter(rgb,19,95,95)
plt.imshow(bl)

# %%
imageObject = Image.fromarray(median)
sharpened1 = imageObject.filter(ImageFilter.SHARPEN)
sharpened2 = sharpened1.filter(ImageFilter.SHARPEN)
sharpened2.save("med9_sharpened.png")

# %%
kernel = np.array([[-1,-1,-1], [-1,9,-1], [-1,-1,-1]])
im = cv2.filter2D(median, -1, kernel)
imageObject = Image.fromarray(im)
imageObject.save("med9_sharpened.png")
