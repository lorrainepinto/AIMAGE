# %% [markdown]
# Applies knowledge from 2 & 3 to our use case

# %%
from PIL import Image
import matplotlib.pyplot as plt
import cv2
import numpy as np

# %%
image = cv2.imread('trial2.jpeg')
#image = image[250:1750 , 800:2000]
rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
plt.imshow(rgb)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-2-b97d5d7b3c71> in <module>
#       1 image = cv2.imread('trial2.jpeg')
#       2 #image = image[250:1750 , 800:2000]
# ----> 3 rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
#       4 hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
#       5 plt.imshow(rgb)
#
# error: OpenCV(4.5.3) C:\Users\runneradmin\AppData\Local\Temp\pip-req-build-uzca7qz1\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'

# %%
#taken from 2_hsv trackbar for this image
u_green = np.array([36, 255, 255])
l_green = np.array([0, 0, 0])

# %%
mask = cv2.inRange(hsv, l_green, u_green)
#masking HSV value selected color becomes black
res = cv2.bitwise_and(rgb,rgb, mask=mask)

# %%
plt.imshow(res)

# %%
# new_image = Image.fromarray(res)
# plt.imshow(new_image)
# new_image.save("test2.png")
